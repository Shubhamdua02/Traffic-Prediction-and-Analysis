# %%
import pandas as pd

# %%
df = pd.read_csv("dot_traffic_2015.txt.gz", header=0, sep=',', quotechar='"')

# %%
df.head()
# Out:
#          date  day_of_data  day_of_week  direction_of_travel  \
# 0  2015-04-07            7            3                    1
# 1  2015-09-26           26            7                    7
# 2  2015-06-16           16            3                    3
# 3  2015-04-26           26            1                    5
# 4  2015-05-23           23            7                    3
#
#   direction_of_travel_name  fips_state_code functional_classification  \
# 0                    North               56                        3R
# 1                     West               21                        1U
# 2                     East                6                        1U
# 3                    South               55                        1U
# 4                     East                4                        4R
#
#            functional_classification_name  lane_of_travel  month_of_data  ...  \
# 0       Rural: Principal Arterial - Other               1              4  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7140391 entries, 0 to 7140390
# Data columns (total 38 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   date                                       object
#  1   day_of_data                                int64
#  2   day_of_week                                int64
#  3   direction_of_travel                        int64
#  4   direction_of_travel_name                   object
#  5   fips_state_code                            int64
#  6   functional_classification                  object
#  7   functional_classification_name             object
#  8   lane_of_travel                             int64
#  9   month_of_data                              int64
#  10  record_type                                int64
#  11  restrictions                               float64
#  12  station_id                                 object
# ...

# %%
df_sc = df.loc[df['fips_state_code'] == 45,:]

# %%
df_sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42928 entries, 131 to 7140249
# Data columns (total 38 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   date                                       42928 non-null  object
#  1   day_of_data                                42928 non-null  int64
#  2   day_of_week                                42928 non-null  int64
#  3   direction_of_travel                        42928 non-null  int64
#  4   direction_of_travel_name                   42928 non-null  object
#  5   fips_state_code                            42928 non-null  int64
#  6   functional_classification                  42928 non-null  object
#  7   functional_classification_name             42928 non-null  object
#  8   lane_of_travel                             42928 non-null  int64
#  9   month_of_data                              42928 non-null  int64
# ...

# %%
df_nc = df.loc[df['fips_state_code'] == 37,:]

# %%
df_final = df_nc.append([df_sc])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87152 entries, 122 to 7140249
# Data columns (total 38 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   date                                       87152 non-null  object
#  1   day_of_data                                87152 non-null  int64
#  2   day_of_week                                87152 non-null  int64
#  3   direction_of_travel                        87152 non-null  int64
#  4   direction_of_travel_name                   87152 non-null  object
#  5   fips_state_code                            87152 non-null  int64
#  6   functional_classification                  87152 non-null  object
#  7   functional_classification_name             87152 non-null  object
#  8   lane_of_travel                             87152 non-null  int64
#  9   month_of_data                              87152 non-null  int64
# ...

# %%
df_final.to_csv('final_dataset.csv', index=False)

# %%
df_stations = pd.read_csv("dot_traffic_stations_2015.txt.gz", header=0, sep=',', quotechar='"')

# %%
df_stations.head()
# Out:
#   algorithm_of_vehicle_classification  \
# 0                                 NaN
# 1                                 NaN
# 2                                   G
# 3                                   D
# 4                                   G
#
#   algorithm_of_vehicle_classification_name calibration_of_weighing_system  \
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2      Axle spacing with Scheme F modified                            NaN
# 3            Vehicle length classification                              M
# 4      Axle spacing with Scheme F modified                              0
#
#            calibration_of_weighing_system_name  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  Moving average of the steering axle of 3S2s
# ...

# %%
df_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28466 entries, 0 to 28465
# Data columns (total 55 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   algorithm_of_vehicle_classification               18576 non-null  object
#  1   algorithm_of_vehicle_classification_name          17335 non-null  object
#  2   calibration_of_weighing_system                    8165 non-null   object
#  3   calibration_of_weighing_system_name               6681 non-null   object
#  4   classification_system_for_vehicle_classification  28466 non-null  int64
#  5   concurrent_route_signing                          28466 non-null  int64
#  6   concurrent_signed_route_number                    13592 non-null  object
#  7   direction_of_travel                               28466 non-null  int64
#  8   direction_of_travel_name                          28466 non-null  object
# ...

# %%
df_stations['station_id'].value_counts()
# Out:
# 000003    72
# 000002    60
# 000004    55
# 000001    53
# 000012    53
#           ..
# 970311     1
# S00DRM     1
# 090744     1
# 069644     1
# 795305     1
# Name: station_id, Length: 6260, dtype: int64

# %%
df_stations_sc = df_stations.loc[df_stations['fips_state_code'] == 45,:]

# %%
df_stations_nc = df_stations.loc[df_stations['fips_state_code'] == 37,:]

# %%
df_stations_final = df_stations_nc.append([df_stations_sc])

# %%
df_stations_final.to_csv('final_stations_dataset.csv', index=False)

# %%
cols = df_stations_final[['latitude','longitude','station_id']]

# %%
cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 595 entries, 38 to 28284
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    595 non-null    float64
#  1   longitude   595 non-null    float64
#  2   station_id  595 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 18.6+ KB

# %%
df_final_latlong = df_final.merge(cols, on='station_id', how='inner')

# %%
df_final_latlong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132912 entries, 0 to 132911
# Data columns (total 40 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   date                                       132912 non-null  object
#  1   day_of_data                                132912 non-null  int64
#  2   day_of_week                                132912 non-null  int64
#  3   direction_of_travel                        132912 non-null  int64
#  4   direction_of_travel_name                   132912 non-null  object
#  5   fips_state_code                            132912 non-null  int64
#  6   functional_classification                  132912 non-null  object
#  7   functional_classification_name             132912 non-null  object
#  8   lane_of_travel                             132912 non-null  int64
#  9   month_of_data                              132912 non-null  int64
# ...

# %%
df_final_latlong.to_csv('final_dataset_lat.csv', index=False)

# %%
df_final_latlong.drop_duplicates(inplace=True)

# %%
df_final_latlong
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87152 entries, 0 to 132911
# Data columns (total 40 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   date                                       87152 non-null  object
#  1   day_of_data                                87152 non-null  int64
#  2   day_of_week                                87152 non-null  int64
#  3   direction_of_travel                        87152 non-null  int64
#  4   direction_of_travel_name                   87152 non-null  object
#  5   fips_state_code                            87152 non-null  int64
#  6   functional_classification                  87152 non-null  object
#  7   functional_classification_name             87152 non-null  object
#  8   lane_of_travel                             87152 non-null  int64
#  9   month_of_data                              87152 non-null  int64
# ...

# %%
df_final_latlong.to_csv('final_dataset_lat.csv', index=False)
